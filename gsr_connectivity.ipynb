# %% [markdown]
# Analyzing connectivity and GSR data

# %%
import pandas as pd
import numpy
import seaborn as sns

# %%
df = pd.read_csv('/home/or/kpe_task_analysis/testing.csv')
df
# Out:
#      Unnamed: 0  Event.Nr  CDA.nSCR CDA.Latency CDA.AmpSum  CDA.SCR  CDA.ISCR  \
# 0             0         1       0.0      0.9016     0.4052   0.3246    0.3246
# 1             1         2       0.0     -0.4428    -0.2334  -0.3044   -0.3044
# 2             2         3       1.0     -0.6008     2.5474   2.5263    2.5263
# 3             3         4       1.0      0.9343    -0.4966  -0.5809   -0.5809
# 4             4         5       0.0      0.7267    -0.5134  -0.5891   -0.5891
# ..          ...       ...       ...         ...        ...      ...       ...
# 346         346         5      -1.0         NaN    -0.5292   1.5509    1.5509
# 347         347         6       1.0      1.2089    -0.4638  -0.5711   -0.5711
# 348         348         7       1.0     -1.0907    -0.4425  -0.5754   -0.5754
# 349         349         8       1.0     -0.7968     0.8222  -0.0599   -0.0599
# 350         350         9      -1.0         NaN    -0.5292  -0.6053   -0.6053
#
# ...
